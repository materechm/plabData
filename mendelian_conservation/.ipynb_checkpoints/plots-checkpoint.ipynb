# %%
import pandas
import seaborn 
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats.stats import pearsonr

# %%
data = pandas.read_csv('~/plabData/yeast_replaceable_genes/sequences/all_other_mendelian/testPlot.csv')

# %%
len(data)
# Out:
# 655

# %%
seaborn.set(style='whitegrid')
seaborn.set_palette("husl")

# %%
g = seaborn.violinplot(data.TypeJS, data.ScoreJS, bw=0.3, inner="quartile")
plt.ylim((0.0,1.0));
plt.xlabel('')
plt.ylabel('Score')

# %%
g = seaborn.violinplot(data.TypeSE, data.ScoreSE, bw=0.3, inner="quartile")
plt.ylim((-0.1,1.2));
plt.xlabel('')
plt.ylabel('Score')

# %%
g = seaborn.violinplot(data.TypeSOP, data.ScoreSOP, bw=0.3, inner="quartile")
plt.ylim((-2,7));
plt.xlabel('')
plt.ylabel('Score')

# %%
g2 = seaborn.stripplot(x="TypeJS", y="ScoreJS", data=data, jitter=True)
plt.ylim((0.0,1.0));

# %%
g2 = seaborn.stripplot(x="TypeSE", y="ScoreSE", data=data, jitter=True)

# %%
g2 = seaborn.stripplot(x="TypeSOP", y="ScoreSOP", data=data, jitter=True)

# %%
g3 = seaborn.regplot(x="pAverage", y="mutationNumber", data=data, fit_reg=False)

# %%
g3 = seaborn.regplot(x="conservation", y="mutationNumber", data=data, fit_reg=False)

# %%
data.corr(method='pearson', min_periods=1)
# Out:
#                  ScoreJS   ScoreSE  ScoreSOP  pAverage  mutationNumber  \
# ScoreJS         1.000000  0.399041  0.359537 -0.105872        0.036015
# ScoreSE         0.399041  1.000000  0.880047 -0.158698        0.057683
# ScoreSOP        0.359537  0.880047  1.000000 -0.201814        0.052959
# pAverage       -0.105872 -0.158698 -0.201814  1.000000       -0.361300
# mutationNumber  0.036015  0.057683  0.052959 -0.361300        1.000000
# conservation    0.094314  0.045875  0.064933 -0.474494        0.080973
# species        -0.063640  0.011951  0.002172  0.020817       -0.122949
# fcm/faa         0.088379  0.086774  0.095244 -0.454380        0.643165
#
#                 conservation   species   fcm/faa
# ScoreJS             0.094314 -0.063640  0.088379
# ScoreSE             0.045875  0.011951  0.086774
# ScoreSOP            0.064933  0.002172  0.095244
# pAverage           -0.474494  0.020817 -0.454380
# mutationNumber      0.080973 -0.122949  0.643165
# conservation        1.000000 -0.339435  0.299835
# species            -0.339435  1.000000  0.097653
# fcm/faa             0.299835  0.097653  1.000000

# %%
g4 = seaborn.regplot(x="pAverage", y="conservation", data=data, fit_reg=False)

# %%
g4 = seaborn.regplot(x="pAverage", y="species", data=data, fit_reg=False)

# %%
g5 = seaborn.lmplot(x="fcm/faa", y="mutationNumber", data=data, fit_reg=False)

# %%
g5 = seaborn.lmplot(x="fcm/faa", y="conservation", data=data, fit_reg=False)
