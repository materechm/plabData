# %%
import pandas
import seaborn 
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats.stats import pearsonr

# %%
data = pandas.read_csv('/Users/mtchavez/plabData/yeast_replaceable_genes/sequences/all_other_mendelian/testPlot.csv')

# %%
len(data)
# Out:
# 369

# %%
seaborn.set(style='whitegrid')
seaborn.set_palette("husl")

# %%
g = seaborn.violinplot(data.TypeJS, data.ScoreJS, bw=0.3, inner="quartile")
plt.ylim((0.0,1.0));
plt.xlabel('')
plt.ylabel('Score')

# %%
g = seaborn.violinplot(data.TypeSE, data.ScoreSE, bw=0.3, inner="quartile")
plt.ylim((-0.1,1.2));
plt.xlabel('')
plt.ylabel('Score')

# %%
g = seaborn.violinplot(data.TypeSOP, data.ScoreSOP, bw=0.3, inner="quartile")
plt.ylim((-2,7));
plt.xlabel('')
plt.ylabel('Score')

# %%
g2 = seaborn.stripplot(x="TypeJS", y="ScoreJS", data=data, jitter=True)

# %%
g2 = seaborn.stripplot(x="TypeSE", y="ScoreSE", data=data, jitter=True)

# %%
g2 = seaborn.stripplot(x="TypeSOP", y="ScoreSOP", data=data, jitter=True)

# %%
g3 = seaborn.regplot(x="pAverage", y="mutationNumber", data=data, fit_reg=False)

# %%
g3 = seaborn.regplot(x="conservation", y="mutationNumber", data=data, fit_reg=False)

# %%
data.corr(method='pearson', min_periods=1)
# Out:
#                  ScoreJS   ScoreSE  ScoreSOP  pAverage  mutationNumber  \
# ScoreJS         1.000000  0.521091  0.741425 -0.002405        0.023977
# ScoreSE         0.521091  1.000000  0.715507 -0.056551        0.007325
# ScoreSOP        0.741425  0.715507  1.000000 -0.027750        0.014277
# pAverage       -0.002405 -0.056551 -0.027750  1.000000       -0.106251
# mutationNumber  0.023977  0.007325  0.014277 -0.106251        1.000000
# conservation    0.207456  0.160011  0.170509 -0.236843        0.192353
# species        -0.102869 -0.015896 -0.060351  0.036409       -0.265230
# fcm/faa         0.158380  0.151783  0.144112 -0.236062        0.667987
#
#                 conservation   species   fcm/faa
# ScoreJS             0.207456 -0.102869  0.158380
# ScoreSE             0.160011 -0.015896  0.151783
# ScoreSOP            0.170509 -0.060351  0.144112
# pAverage           -0.236843  0.036409 -0.236062
# mutationNumber      0.192353 -0.265230  0.667987
# conservation        1.000000 -0.451417  0.343474
# species            -0.451417  1.000000 -0.028532
# fcm/faa             0.343474 -0.028532  1.000000

# %%
g4 = seaborn.regplot(x="pAverage", y="conservation", data=data, fit_reg=False)

# %%
g4 = seaborn.regplot(x="pAverage", y="species", data=data, fit_reg=False)

# %%
g5 = seaborn.lmplot(x="fcm/faa", y="mutationNumber", data=data, fit_reg=False)

# %%
g5 = seaborn.lmplot(x="fcm/faa", y="conservation", data=data, fit_reg=False)
