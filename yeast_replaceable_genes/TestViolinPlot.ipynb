# %%
import pandas
import seaborn 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pandas.read_csv('/Users/mtchavez/plabData/yeast_replaceable_genes/sequences/all_other_mendelian/testPlot.csv')

# %%
len(data)
# Out:
# 334

# %%
seaborn.set(style='whitegrid')
seaborn.set_palette("husl")

# %%
g = seaborn.violinplot(data.TypeJS, data.ScoreJS, bw=0.3, inner="quartile")
plt.ylim((0.0,1.0));
plt.xlabel('')
plt.ylabel('Score')

# %%
g = seaborn.violinplot(data.TypeSE, data.ScoreSE, bw=0.3, inner="quartile")
plt.ylim((-0.1,1));
plt.xlabel('')
plt.ylabel('Score')

# %%
g = seaborn.violinplot(data.TypeSOP, data.ScoreSOP, bw=0.3, inner="quartile")
plt.ylim((-2,6));
plt.xlabel('')
plt.ylabel('Score')

# %%
g2 = seaborn.stripplot(x="TypeJS", y="ScoreJS", data=data, jitter=True)

# %%
g2 = seaborn.stripplot(x="TypeSE", y="ScoreSE", data=data, jitter=True)

# %%
g2 = seaborn.stripplot(x="TypeSOP", y="ScoreSOP", data=data, jitter=True)

# %%
g3 = seaborn.violinplot(data.TypeJS, data.ScoreJS, bw=0.3, inner="quartile")
g3 = seaborn.stripplot(x="TypeJS", y="ScoreJS", data=data, jitter=True)

# %%
g3 = seaborn.violinplot(data.TypeSE, data.ScoreSE, bw=0.3, inner="quartile")
g3 = seaborn.stripplot(x="TypeSE", y="ScoreSE", data=data, jitter=True)

# %%
g3 = seaborn.violinplot(data.TypeSOP, data.ScoreSOP, bw=0.3, inner="quartile")
g3 = seaborn.stripplot(x="TypeSOP", y="ScoreSOP", data=data, jitter=True)

# %%
g4 = seaborn.regplot(x="pAverage", y="mutationNumber", data=data)

# %%
g5 = seaborn.regplot(x="pAverage", y="speciesNumber", data=data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-ad8a9dac7a40> in <module>()
# ----> 1 g5 = seaborn.regplot(x="pAverage", y="speciesNumber", data=data)
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     762                                  order, logistic, lowess, robust, logx,
#     763                                  x_partial, y_partial, truncate, dropna,
# --> 764                                  x_jitter, y_jitter, color, label)
#     765
#     766     if ax is None:
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     103         # Extract the data vals from the arguments or passed dataframe
#     104         self.establish_variables(data, x=x, y=y, units=units,
# --> 105                                  x_partial=x_partial, y_partial=y_partial)
#     106
#     107         # Drop null observations
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in establish_variables(self, data, **kws)
#      48         for var, val in kws.items():
#      49             if isinstance(val, string_types):
# ---> 50                 setattr(self, var, data[val])
#      51             else:
#      52                 setattr(self, var, val)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1082         res = cache.get(item)
#    1083         if res is None:
# -> 1084             values = self._data.get(item)
#    1085             res = self._box_item_values(item, values)
#    1086             cache[item] = res
#
# //anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    2849
#    2850             if not isnull(item):
# -> 2851                 loc = self.items.get_loc(item)
#    2852             else:
#    2853                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# //anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method)
#    1570         """
#    1571         if method is None:
# -> 1572             return self._engine.get_loc(_values_from_object(key))
#    1573
#    1574         indexer = self.get_indexer([key], method=method)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3824)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3704)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12280)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12231)()
#
# KeyError: 'speciesNumber'

# %%
g6 = seaborn.regplot(x="pAverage", y="conservationAverage", data=data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-bd9c033fcc15> in <module>()
# ----> 1 g6 = seaborn.regplot(x="pAverage", y="conservationAverage", data=data)
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     762                                  order, logistic, lowess, robust, logx,
#     763                                  x_partial, y_partial, truncate, dropna,
# --> 764                                  x_jitter, y_jitter, color, label)
#     765
#     766     if ax is None:
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     103         # Extract the data vals from the arguments or passed dataframe
#     104         self.establish_variables(data, x=x, y=y, units=units,
# --> 105                                  x_partial=x_partial, y_partial=y_partial)
#     106
#     107         # Drop null observations
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in establish_variables(self, data, **kws)
#      48         for var, val in kws.items():
#      49             if isinstance(val, string_types):
# ---> 50                 setattr(self, var, data[val])
#      51             else:
#      52                 setattr(self, var, val)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1082         res = cache.get(item)
#    1083         if res is None:
# -> 1084             values = self._data.get(item)
#    1085             res = self._box_item_values(item, values)
#    1086             cache[item] = res
#
# //anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    2849
#    2850             if not isnull(item):
# -> 2851                 loc = self.items.get_loc(item)
#    2852             else:
#    2853                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# //anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method)
#    1570         """
#    1571         if method is None:
# -> 1572             return self._engine.get_loc(_values_from_object(key))
#    1573
#    1574         indexer = self.get_indexer([key], method=method)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3824)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3704)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12280)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12231)()
#
# KeyError: 'conservationAverage'
